# %% [markdown]
# ### Corona Lung Image Data Analysis using CNN

# %% [markdown]
# Corona Lung Image Data Analysis using CNN
# Aim: study of lungs images and telling whether the person is effected with corona or not effected.
#
# !pip install opencv-python
#
# Problem statement: In this Section we are implementing Convolution Neural Network(CNN) Classifier for Classifying corona and normal images.

# %%
#!pip install opencv-python
#!pip install tensorflow

# %%
import tensorflow
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import ZeroPadding2D
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import RMSprop,SGD,Adam

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from concurrent.futures import ThreadPoolExecutor

# %%
import cv2 
import os
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Datascience course'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set({'figure.facecolor':'yellow'})

import warnings
warnings.filterwarnings('ignore')

# %%
#reading the single image
loading_img = cv2.imread("C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\data\\Data\\train\\Covid\\covid (1).jpeg", 0) / 255
plt.imshow(loading_img, cmap='gray', vmin=0, vmax=1) 
sns.set({'figure.facecolor':'blue'})
plt.show()

# %%
#initializing the neural network model
classifier = Sequential()
classifier.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2),strides=2)) #if stride not given it equal to pool filter size
classifier.add(Conv2D(32,(3,3),activation = 'relu'))
classifier.add(MaxPooling2D(pool_size=(2,2),strides=2))

#flattening transforms a 2-D matrix of features into a vector of features
classifier.add(Flatten())

#adding hidden layers
classifier.add(Dense(units=128,activation='relu'))
#adding output layers
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 31, 31, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 6272)              0
#
#  dense_6 (Dense)             (None, 128)               802944
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 813,217
# Trainable params: 813,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# specifying optimizers: is used to reduce the cost calculated by entropy, the loss function is used to calculate the error, the metrics used to represent the efficiency of the model

# %%
adam = tensorflow.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
classifier.compile(optimizer=adam,loss='binary_crossentropy',metrics=['accuracy','Precision','Recall'])
classifier
#tensorboard = TensorBoard(log_dir="logs/{}".format(time()))

# %% [markdown]
# setting the data directory and generate image data

# %%
#setting training data directory
train_dir=('C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\data\\Data\\train\\')
#setting testing data directory
validation_dir=('C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\data\\Data\\validate\\')

# %%
#all images will be rescaled by 1./255
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#spliting train and test data using imagedatagenerator
#train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.1,zoom_range=0.1,horizontal_flip=True)
#test_datagen = ImageDataGenerator(rescale=1./255)

#DataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                    featurewise_center=True, 
                                    samplewise_center=True, 
                                    featurewise_std_normalization=True, 
                                    samplewise_std_normalization=True, 
                                    zca_whitening=False, zca_epsilon=1e-06, 
                                    rotation_range=40, width_shift_range=0.0,
                                    height_shift_range=0.0, brightness_range=(0.2, 0.2),
                                    shear_range=0.2, zoom_range=0.2, 
                                    channel_shift_range=0.0, fill_mode='nearest', 
                                    cval=0.0, horizontal_flip=True, vertical_flip=True,
                                    data_format=None, validation_split=0.0, dtype=None)
#validating
test_datagen = ImageDataGenerator(rescale = 1./255,
                                    featurewise_center=True, 
                                    samplewise_center=True, 
                                    featurewise_std_normalization=True, 
                                    samplewise_std_normalization=True, 
                                    zca_whitening=False, zca_epsilon=1e-06, 
                                    rotation_range=40, width_shift_range=0.0,
                                    height_shift_range=0.0, brightness_range=(0.2, 0.2),
                                    shear_range=0.2, zoom_range=0.2, 
                                    channel_shift_range=0.0, fill_mode='nearest', 
                                    cval=0.0, horizontal_flip=True, vertical_flip=True,
                                    data_format=None, validation_split=0.0, dtype=None)

# %% [markdown]
# Creating Training, Validation, and Testing Directories

# %%
#flow training images in batches using generator
#Training Set
#train_file='C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\data\\Data\\train\\'
train_set = train_datagen.flow_from_directory(train_dir,
                                             target_size=(64,64),
                                             batch_size=64,
                                             class_mode='binary')
#flow training images in batches using generator
#Validation Set
#val_file='C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\data\\Data\\validate\\'
validation_set = test_datagen.flow_from_directory(validation_dir,
                                           target_size=(64,64),
                                           batch_size = 64,
                                           class_mode='binary',
                                           shuffle=False)
#Test Set /no output available
#test_set1 = test_datagen.flow_from_directory('test1',target_size=(64,64),batch_size=32,shuffle=False)
# Out:
# Found 243 images belonging to 2 classes.
# Found 54 images belonging to 2 classes.

# %%
#Fitting Model
history = classifier.fit_generator(train_set,validation_data=validation_set,steps_per_epoch=150//32,epochs=30,validation_steps=50//32,verbose=2)
# Out:
# Epoch 1/30
# 4/4 - 87s - loss: 0.8338 - accuracy: 0.5309 - precision: 0.5273 - recall: 0.4833 - val_loss: 0.5332 - val_accuracy: 0.7407 - val_precision: 0.8333 - val_recall: 0.5769 - 87s/epoch - 22s/step
# Epoch 2/30
# 4/4 - 58s - loss: 0.4190 - accuracy: 0.8025 - precision: 0.7812 - recall: 0.8333 - val_loss: 0.4352 - val_accuracy: 0.7778 - val_precision: 0.6842 - val_recall: 1.0000 - 58s/epoch - 15s/step
# Epoch 3/30
# 4/4 - 60s - loss: 0.3781 - accuracy: 0.8477 - precision: 0.7862 - recall: 0.9500 - val_loss: 0.2834 - val_accuracy: 0.8704 - val_precision: 0.8276 - val_recall: 0.9231 - 60s/epoch - 15s/step
# Epoch 4/30
# 4/4 - 62s - loss: 0.3315 - accuracy: 0.8642 - precision: 0.8655 - recall: 0.8583 - val_loss: 0.2763 - val_accuracy: 0.8519 - val_precision: 0.8214 - val_recall: 0.8846 - 62s/epoch - 15s/step
# Epoch 5/30
# 4/4 - 64s - loss: 0.2869 - accuracy: 0.8848 - precision: 0.8433 - recall: 0.9417 - val_loss: 0.2176 - val_accuracy: 0.9074 - val_precision: 0.8387 - val_recall: 1.0000 - 64s/epoch - 16s/step
# Epoch 6/30
# 4/4 - 60s - loss: 0.2926 - accuracy: 0.8683 - precision: 0.7973 - recall: 0.9833 - val_loss: 0.2641 - val_accuracy: 0.8889 - val_precision: 0.8333 - val_recall: 0.9615 - 60s/epoch - 15s/step
# Epoch 7/30
# 4/4 - 62s - loss: 0.2480 - accuracy: 0.8930 - precision: 0.8561 - recall: 0.9417 - val_loss: 0.1986 - val_accuracy: 0.9259 - val_precision: 0.9231 - val_recall: 0.9231 - 62s/epoch - 16s/step
# Epoch 8/30
# 4/4 - 59s - loss: 0.2766 - accuracy: 0.8889 - precision: 0.8661 - recall: 0.9167 - val_loss: 0.2333 - val_accuracy: 0.8889 - val_precision: 0.8846 - val_recall: 0.8846 - 59s/epoch - 15s/step
# Epoch 9/30
# 4/4 - 58s - loss: 0.1938 - accuracy: 0.9095 - precision: 0.8712 - recall: 0.9583 - val_loss: 0.2103 - val_accuracy: 0.9074 - val_precision: 0.8621 - val_recall: 0.9615 - 58s/epoch - 14s/step
# Epoch 10/30
# 4/4 - 62s - loss: 0.1875 - accuracy: 0.9300 - precision: 0.8815 - recall: 0.9917 - val_loss: 0.1376 - val_accuracy: 0.9630 - val_precision: 0.9615 - val_recall: 0.9615 - 62s/epoch - 15s/step
# Epoch 11/30
# 4/4 - 77s - loss: 0.1498 - accuracy: 0.9465 - precision: 0.9084 - recall: 0.9917 - val_loss: 0.1882 - val_accuracy: 0.9259 - val_precision: 0.9583 - val_recall: 0.8846 - 77s/epoch - 19s/step
# Epoch 12/30
# 4/4 - 62s - loss: 0.1589 - accuracy: 0.9383 - precision: 0.9268 - recall: 0.9500 - val_loss: 0.0878 - val_accuracy: 0.9630 - val_precision: 0.9286 - val_recall: 1.0000 - 62s/epoch - 15s/step
# Epoch 13/30
# 4/4 - 50s - loss: 0.1324 - accuracy: 0.9383 - precision: 0.8947 - recall: 0.9917 - val_loss: 0.0806 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 50s/epoch - 13s/step
# Epoch 14/30
# 4/4 - 52s - loss: 0.1433 - accuracy: 0.9424 - precision: 0.9206 - recall: 0.9667 - val_loss: 0.0935 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 52s/epoch - 13s/step
# Epoch 15/30
# 4/4 - 64s - loss: 0.1037 - accuracy: 0.9671 - precision: 0.9444 - recall: 0.9917 - val_loss: 0.0584 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 64s/epoch - 16s/step
# Epoch 16/30
# 4/4 - 67s - loss: 0.1081 - accuracy: 0.9506 - precision: 0.9355 - recall: 0.9667 - val_loss: 0.0923 - val_accuracy: 0.9630 - val_precision: 1.0000 - val_recall: 0.9231 - 67s/epoch - 17s/step
# Epoch 17/30
# 4/4 - 57s - loss: 0.1192 - accuracy: 0.9300 - precision: 0.9256 - recall: 0.9333 - val_loss: 0.0710 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 57s/epoch - 14s/step
# Epoch 18/30
# 4/4 - 62s - loss: 0.0778 - accuracy: 0.9753 - precision: 0.9524 - recall: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 62s/epoch - 15s/step
# Epoch 19/30
# 4/4 - 72s - loss: 0.0890 - accuracy: 0.9671 - precision: 0.9667 - recall: 0.9667 - val_loss: 0.0484 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 72s/epoch - 18s/step
# Epoch 20/30
# 4/4 - 60s - loss: 0.0759 - accuracy: 0.9630 - precision: 0.9302 - recall: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 60s/epoch - 15s/step
# Epoch 21/30
# 4/4 - 58s - loss: 0.1194 - accuracy: 0.9465 - precision: 0.9735 - recall: 0.9167 - val_loss: 0.1116 - val_accuracy: 0.9444 - val_precision: 1.0000 - val_recall: 0.8846 - 58s/epoch - 14s/step
# Epoch 22/30
# 4/4 - 59s - loss: 0.0710 - accuracy: 0.9835 - precision: 0.9754 - recall: 0.9917 - val_loss: 0.0917 - val_accuracy: 0.9630 - val_precision: 0.9286 - val_recall: 1.0000 - 59s/epoch - 15s/step
# Epoch 23/30
# 4/4 - 63s - loss: 0.1009 - accuracy: 0.9547 - precision: 0.9225 - recall: 0.9917 - val_loss: 0.0561 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 63s/epoch - 16s/step
# Epoch 24/30
# 4/4 - 58s - loss: 0.0880 - accuracy: 0.9712 - precision: 0.9913 - recall: 0.9500 - val_loss: 0.1032 - val_accuracy: 0.9630 - val_precision: 1.0000 - val_recall: 0.9231 - 58s/epoch - 14s/step
# Epoch 25/30
# 4/4 - 60s - loss: 0.0639 - accuracy: 0.9712 - precision: 0.9593 - recall: 0.9833 - val_loss: 0.0612 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 60s/epoch - 15s/step
# Epoch 26/30
# 4/4 - 63s - loss: 0.0684 - accuracy: 0.9794 - precision: 0.9752 - recall: 0.9833 - val_loss: 0.0548 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - 63s/epoch - 16s/step
# Epoch 27/30
# 4/4 - 58s - loss: 0.0507 - accuracy: 0.9835 - precision: 0.9754 - recall: 0.9917 - val_loss: 0.0885 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 58s/epoch - 15s/step
# Epoch 28/30
# 4/4 - 59s - loss: 0.0531 - accuracy: 0.9835 - precision: 0.9754 - recall: 0.9917 - val_loss: 0.0843 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 59s/epoch - 15s/step
# Epoch 29/30
# 4/4 - 59s - loss: 0.0516 - accuracy: 0.9835 - precision: 0.9677 - recall: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9630 - val_precision: 1.0000 - val_recall: 0.9231 - 59s/epoch - 15s/step
# Epoch 30/30
# 4/4 - 60s - loss: 0.0408 - accuracy: 0.9959 - precision: 1.0000 - recall: 0.9917 - val_loss: 0.0851 - val_accuracy: 0.9815 - val_precision: 1.0000 - val_recall: 0.9615 - 60s/epoch - 15s/step

# %% [markdown]
# fit function is used when the entire training dataset can fit into the memory and no data agumentation is applied. fit_generator is used when either we have a huge dataset to fit into our memory or when data agumentation needs to be applied

# %% [markdown]
# The above function trains the neural network using the traing set and evaluates its performance on the test set. the function returns the metrics for each epoch which are predictions obtained in the training set and test set

# %% [markdown]
# Plotting the performance metrics graphs

# %%
import matplotlib.pyplot as plt

print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'],'green')
plt.plot(history.history['val_accuracy'],'yellow')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

plt.title('loss')
# summarize history for loss
plt.plot(history.history['loss'],'green')
plt.plot(history.history['val_loss'],'yellow')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# summarize history for accuracy
plt.plot(history.history['precision'],'green')
plt.plot(history.history['val_precision'],'yellow')
plt.title('model precision')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()
# summarize history for loss
plt.plot(history.history['recall'],'green')
plt.plot(history.history['val_recall'],'yellow')
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower center')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall'])

# %%
from sklearn import metrics
y_pred = (classifier.predict_generator(validation_set) > 0.5).astype(int)
y_true = validation_set.classes

for name, value in zip(classifier.metrics_names, classifier.evaluate_generator(validation_set)):
    print(f'{name}: {value}')
print(f'F1 score: {metrics.f1_score(y_true, y_pred)}')
# Out:
# loss: 0.029802830889821053
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# F1 score: 1.0

# %%
classifier.save("C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\model\\covid_prediction.h5")

# %%
from keras.models import load_model
test_model = load_model("C:\\Users\\Dell\\Desktop\\Corona Lung Data Set\\model\\covid_prediction.h5")
test_model
